# %% [markdown]
# Stakeholder: Growth/Strategy Team
#
# 1. Where should we expand (city / country) to maximize highly-rated restaurants with low supply?
# 2. Which cuisine gaps exist by city (high demand, low supply)?
# 3. Which price ranges produce best ratings per city?

# %% [markdown]
# Q1: Where should we expand (city/country) to maximize highly-rated restaurants with low supply?
#
# Parameters Required:
